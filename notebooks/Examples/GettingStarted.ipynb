# %% [markdown]
# # Getting started

# %% [markdown]
# ### Experimental setup
# <img src="ledHookup.png" alt="LED" style="width: 300px;"/>

# %%
import numpy as np
from lightlab.equipment.lab_instruments import Keithley_2400_SM
from lightlab.util.sweep import NdSweeper

# %% [markdown]
# ### Initialize an instrument

# %%
keithley = Keithley_2400_SM(name='A source meter', address='GPIB0::16::INSTR')

# %% [markdown]
# ### Define a sweep

# %%
swp = NdSweeper()
swp.addActuation('voltage', keithley.setVoltage, np.linspace(0, 1, 20))
swp.addMeasurement('current', keithley.measCurrent)

# %% [markdown]
# ### Run the sweep

# %%
swp.gather()
swp.plot()
swp.saveObj('new-iv-sweep')
# Out:
# Printing progress in tempfile C:\Users\mrnez\OneDrive\Documents\GitHub\lightlab\progress-monitor\swp_progzch07f90
# Generic sweep in voltage
# Dim-0...
# 1/20...
# 2020-08-18 19:29:07,896 - WARNING - lightlab.visa:
# 	There was a problem opening the VISA GPIB0::16::INSTR... Error code: StatusCode.error_library_not_found
# 2020-08-18 19:29:08,403 - WARNING - lightlab.visa:
# 	Trying again... (try = 1/5)
# 2020-08-18 19:29:08,403 - WARNING - lightlab.visa:
# 	There was a problem opening the VISA GPIB0::16::INSTR... Error code: StatusCode.error_library_not_found
# 2020-08-18 19:29:09,414 - WARNING - lightlab.visa:
# 	Trying again... (try = 2/5)
# 2020-08-18 19:29:09,422 - WARNING - lightlab.visa:
# 	There was a problem opening the VISA GPIB0::16::INSTR... Error code: StatusCode.error_library_not_found
# 2020-08-18 19:29:10,933 - WARNING - lightlab.visa:
# 	Trying again... (try = 3/5)
# 2020-08-18 19:29:10,933 - WARNING - lightlab.visa:
# 	There was a problem opening the VISA GPIB0::16::INSTR... Error code: StatusCode.error_library_not_found
# 2020-08-18 19:29:12,947 - WARNING - lightlab.visa:
# 	Trying again... (try = 4/5)
# 2020-08-18 19:29:12,954 - WARNING - lightlab.visa:
# 	There was a problem opening the VISA GPIB0::16::INSTR... Error code: StatusCode.error_library_not_found
# 2020-08-18 19:29:15,461 - WARNING - lightlab.visa:
# 	Trying again... (try = 5/5)
# 2020-08-18 19:29:15,461 - WARNING - lightlab.visa:
# 	There was a problem opening the VISA GPIB0::16::INSTR... Error code: StatusCode.error_library_not_found
# 2020-08-18 19:29:15,468 - ERROR - lightlab.visa:
# 	VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
# 2020-08-18 19:29:15,470 - ERROR - lightlab.visa:
# 	Problematic parameter was OUTP:STATE.
# Likely it does not exist in this instrument command structure.
# 2020-08-18 19:29:15,473 - ERROR - lightlab:
# 	Error while sweeping. Keeping data. VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      56         try:
# ---> 57             self.mbSession = self.resMan.open_resource(self.address)
#      58             self.mbSession.write_termination = self.termination
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    1749         if resource_pyclass is None:
# -> 1750             info = self.resource_info(resource_name, extended=True)
#    1751
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in resource_info(self, resource_name, extended)
#    1703         if extended:
# -> 1704             ret, err = self.visalib.parse_resource_extended(self.session, resource_name)
#    1705         else:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\functions.py in parse_resource_extended(library, session, resource_name)
#    1379     # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1380     ret = library.viParseRsrcEx(session, resource_name, byref(interface_type),
#    1381                                 byref(interface_board_number), resource_class,
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     192         if ret_value < 0:
# --> 193             raise errors.VisaIOError(ret_value)
#     194
#
# VisaIOError: VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
#
# During handling of the above exception, another exception occurred:
#
# VisaIOError                               Traceback (most recent call last)
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      56         try:
# ---> 57             self.mbSession = self.resMan.open_resource(self.address)
#      58             self.mbSession.write_termination = self.termination
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    1749         if resource_pyclass is None:
# -> 1750             info = self.resource_info(resource_name, extended=True)
#    1751
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in resource_info(self, resource_name, extended)
#    1703         if extended:
# -> 1704             ret, err = self.visalib.parse_resource_extended(self.session, resource_name)
#    1705         else:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\functions.py in parse_resource_extended(library, session, resource_name)
#    1379     # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1380     ret = library.viParseRsrcEx(session, resource_name, byref(interface_type),
#    1381                                 byref(interface_board_number), resource_class,
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     192         if ret_value < 0:
# --> 193             raise errors.VisaIOError(ret_value)
#     194
#
# VisaIOError: VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
#
# During handling of the above exception, another exception occurred:
#
# VisaIOError                               Traceback (most recent call last)
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      56         try:
# ---> 57             self.mbSession = self.resMan.open_resource(self.address)
#      58             self.mbSession.write_termination = self.termination
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    1749         if resource_pyclass is None:
# -> 1750             info = self.resource_info(resource_name, extended=True)
#    1751
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in resource_info(self, resource_name, extended)
#    1703         if extended:
# -> 1704             ret, err = self.visalib.parse_resource_extended(self.session, resource_name)
#    1705         else:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\functions.py in parse_resource_extended(library, session, resource_name)
#    1379     # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1380     ret = library.viParseRsrcEx(session, resource_name, byref(interface_type),
#    1381                                 byref(interface_board_number), resource_class,
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     192         if ret_value < 0:
# --> 193             raise errors.VisaIOError(ret_value)
#     194
#
# VisaIOError: VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
#
# During handling of the above exception, another exception occurred:
#
# VisaIOError                               Traceback (most recent call last)
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      56         try:
# ---> 57             self.mbSession = self.resMan.open_resource(self.address)
#      58             self.mbSession.write_termination = self.termination
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    1749         if resource_pyclass is None:
# -> 1750             info = self.resource_info(resource_name, extended=True)
#    1751
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in resource_info(self, resource_name, extended)
#    1703         if extended:
# -> 1704             ret, err = self.visalib.parse_resource_extended(self.session, resource_name)
#    1705         else:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\functions.py in parse_resource_extended(library, session, resource_name)
#    1379     # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1380     ret = library.viParseRsrcEx(session, resource_name, byref(interface_type),
#    1381                                 byref(interface_board_number), resource_class,
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     192         if ret_value < 0:
# --> 193             raise errors.VisaIOError(ret_value)
#     194
#
# VisaIOError: VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
#
# During handling of the above exception, another exception occurred:
#
# VisaIOError                               Traceback (most recent call last)
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      56         try:
# ---> 57             self.mbSession = self.resMan.open_resource(self.address)
#      58             self.mbSession.write_termination = self.termination
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    1749         if resource_pyclass is None:
# -> 1750             info = self.resource_info(resource_name, extended=True)
#    1751
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in resource_info(self, resource_name, extended)
#    1703         if extended:
# -> 1704             ret, err = self.visalib.parse_resource_extended(self.session, resource_name)
#    1705         else:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\functions.py in parse_resource_extended(library, session, resource_name)
#    1379     # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1380     ret = library.viParseRsrcEx(session, resource_name, byref(interface_type),
#    1381                                 byref(interface_board_number), resource_class,
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     192         if ret_value < 0:
# --> 193             raise errors.VisaIOError(ret_value)
#     194
#
# VisaIOError: VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
#
# During handling of the above exception, another exception occurred:
#
# VisaIOError                               Traceback (most recent call last)
# <ipython-input-5-8ce7f20d0570> in <module>
# ----> 1 swp.gather()
#       2 swp.plot()
#       3 swp.saveObj('new-iv-sweep')
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\util\sweep.py in gather(self, soakTime, autoSave, returnToStart)
#     234                         pointData[actuKey] = x
#     235                     if iDim == self.actuDims - 1 or index[iDim + 1] == 0 or actuObj.doOnEveryPoint:
# --> 236                         y = actuObj.function(x)  # The actual function call occurs here
#     237                         if y is not None:
#     238                             pointData[actuKey + '-return'] = y
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\lab_instruments\Keithley_2400_SM.py in setVoltage(self, voltVolts)
#     106     def setVoltage(self, voltVolts):
#     107         voltTemp = self._latestVoltageVal
# --> 108         if not self.enable() or self.voltStep is None:
#     109             self._configVoltage(voltVolts)
#     110         else:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\lab_instruments\Keithley_2400_SM.py in enable(self, newState)
#     166         if newState is not None:
#     167             self.setConfigParam('OUTP:STATE', 1 if newState else 0, forceHardware=True)
# --> 168         retVal = self.getConfigParam('OUTP:STATE', forceHardware=True)
#     169         return retVal in ['ON', 1, '1']
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\abstract_drivers\configurable.py in getConfigParam(self, cStr, forceHardware)
#     327             prevVal = None
#     328         if prevVal is None or forceHardware:  # Try getting from hardware
# --> 329             self._getHardwareConfig(cStr)
#     330         if prevVal is None:  # This is the first time getting, so it goes in 'init'
#     331             self.config['init'].transfer(self.config['live'], cStr)
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\abstract_drivers\configurable.py in _getHardwareConfig(self, cStrList)
#     447
#     448             try:
# --> 449                 ret = self.query(cStr + '?')
#     450             except VisaIOError:
#     451                 logger.error('Problematic parameter was %s.\n'
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in query(self, queryStr, withTimeout)
#     103         retStr = None
#     104         try:
# --> 105             self.open()
#     106             logger.debug('%s - Q - %s', self.address, queryStr)
#     107             toutOrig = self.timeout
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      66                 time.sleep(0.5 * self._open_retries)
#      67                 logger.warning('Trying again... (try = %s/%s)', self._open_retries, OPEN_RETRIES)
# ---> 68                 self.open()
#      69             else:
#      70                 logger.error(err)
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      66                 time.sleep(0.5 * self._open_retries)
#      67                 logger.warning('Trying again... (try = %s/%s)', self._open_retries, OPEN_RETRIES)
# ---> 68                 self.open()
#      69             else:
#      70                 logger.error(err)
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      66                 time.sleep(0.5 * self._open_retries)
#      67                 logger.warning('Trying again... (try = %s/%s)', self._open_retries, OPEN_RETRIES)
# ---> 68                 self.open()
#      69             else:
#      70                 logger.error(err)
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      66                 time.sleep(0.5 * self._open_retries)
#      67                 logger.warning('Trying again... (try = %s/%s)', self._open_retries, OPEN_RETRIES)
# ---> 68                 self.open()
#      69             else:
#      70                 logger.error(err)
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      66                 time.sleep(0.5 * self._open_retries)
#      67                 logger.warning('Trying again... (try = %s/%s)', self._open_retries, OPEN_RETRIES)
# ---> 68                 self.open()
#      69             else:
#      70                 logger.error(err)
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      55             self.resMan = pyvisa.ResourceManager()
#      56         try:
# ---> 57             self.mbSession = self.resMan.open_resource(self.address)
#      58             self.mbSession.write_termination = self.termination
#      59             if not self.tempSess:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    1748
#    1749         if resource_pyclass is None:
# -> 1750             info = self.resource_info(resource_name, extended=True)
#    1751
#    1752             try:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in resource_info(self, resource_name, extended)
#    1702
#    1703         if extended:
# -> 1704             ret, err = self.visalib.parse_resource_extended(self.session, resource_name)
#    1705         else:
#    1706             ret, err = self.visalib.parse_resource(self.session, resource_name)
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\functions.py in parse_resource_extended(library, session, resource_name)
#    1378     # [ViSession, ViRsrc, ViPUInt16, ViPUInt16, ViAChar, ViAChar, ViAChar]
#    1379     # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1380     ret = library.viParseRsrcEx(session, resource_name, byref(interface_type),
#    1381                                 byref(interface_board_number), resource_class,
#    1382                                 unaliased_expanded_resource_name,
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     191
#     192         if ret_value < 0:
# --> 193             raise errors.VisaIOError(ret_value)
#     194
#     195         if ret_value in self.issue_warning_on:
#
# VisaIOError: VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.

# %% [markdown]
# ## More advanced
# - user-defined procedures
# - interactive search over functions

# %%
from lightlab.util.search import peakSearch

def dither(centerVolt):
    swp.actuate['voltage'].domain = centerVolt + np.linspace(-.2, .2, 3)
    swp.gather()
    second_derivative = np.diff(swp.data['current'], n=2)
    return second_derivative

foundThresh, _ = peakSearch(dither, [-1, 3])
print(f'Diode threshold is {foundThresh} Volts')
# Out:
# 2020-08-18 19:29:28,669 - WARNING - lightlab.visa:
# 	There was a problem opening the VISA GPIB0::16::INSTR... Error code: StatusCode.error_library_not_found
# 2020-08-18 19:29:28,671 - ERROR - lightlab.visa:
# 	VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
# 2020-08-18 19:29:28,675 - ERROR - lightlab.visa:
# 	Problematic parameter was OUTP:STATE.
# Likely it does not exist in this instrument command structure.
# 2020-08-18 19:29:28,677 - ERROR - lightlab:
# 	Error while sweeping. Keeping data. VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
# Printing progress in tempfile C:\Users\mrnez\OneDrive\Documents\GitHub\lightlab\progress-monitor\swp_prog6wvysfow
# Generic sweep in voltage
# Dim-0...
# 1/20...
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# <ipython-input-6-60468f55cc34> in <module>
#       7     return second_derivative
#       8
# ----> 9 foundThresh, _ = peakSearch(dither, [-1, 3])
#      10 print(f'Diode threshold is {foundThresh} Volts')
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\util\search.py in peakSearch(evalPointFun, startBounds, nSwarm, xTol, yTol, livePlot)
#      76         measuredVals = np.zeros(nSwarm)
#      77         for iPt, offs in enumerate(offsToMeasure):
# ---> 78             meas = evalPointFun(offs)
#      79             measuredVals[iPt] = meas
#      80             tracker.addPoint((offs, meas))
#
# <ipython-input-6-60468f55cc34> in dither(centerVolt)
#       3 def dither(centerVolt):
#       4     swp.actuate['voltage'].domain = centerVolt + np.linspace(-.2, .2, 3)
# ----> 5     swp.gather()
#       6     second_derivative = np.diff(swp.data['current'], n=2)
#       7     return second_derivative
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\util\sweep.py in gather(self, soakTime, autoSave, returnToStart)
#     234                         pointData[actuKey] = x
#     235                     if iDim == self.actuDims - 1 or index[iDim + 1] == 0 or actuObj.doOnEveryPoint:
# --> 236                         y = actuObj.function(x)  # The actual function call occurs here
#     237                         if y is not None:
#     238                             pointData[actuKey + '-return'] = y
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\lab_instruments\Keithley_2400_SM.py in setVoltage(self, voltVolts)
#     106     def setVoltage(self, voltVolts):
#     107         voltTemp = self._latestVoltageVal
# --> 108         if not self.enable() or self.voltStep is None:
#     109             self._configVoltage(voltVolts)
#     110         else:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\lab_instruments\Keithley_2400_SM.py in enable(self, newState)
#     166         if newState is not None:
#     167             self.setConfigParam('OUTP:STATE', 1 if newState else 0, forceHardware=True)
# --> 168         retVal = self.getConfigParam('OUTP:STATE', forceHardware=True)
#     169         return retVal in ['ON', 1, '1']
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\abstract_drivers\configurable.py in getConfigParam(self, cStr, forceHardware)
#     327             prevVal = None
#     328         if prevVal is None or forceHardware:  # Try getting from hardware
# --> 329             self._getHardwareConfig(cStr)
#     330         if prevVal is None:  # This is the first time getting, so it goes in 'init'
#     331             self.config['init'].transfer(self.config['live'], cStr)
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\abstract_drivers\configurable.py in _getHardwareConfig(self, cStrList)
#     447
#     448             try:
# --> 449                 ret = self.query(cStr + '?')
#     450             except VisaIOError:
#     451                 logger.error('Problematic parameter was %s.\n'
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in query(self, queryStr, withTimeout)
#     103         retStr = None
#     104         try:
# --> 105             self.open()
#     106             logger.debug('%s - Q - %s', self.address, queryStr)
#     107             toutOrig = self.timeout
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\lightlab\equipment\visa_bases\visa_object.py in open(self)
#      55             self.resMan = pyvisa.ResourceManager()
#      56         try:
# ---> 57             self.mbSession = self.resMan.open_resource(self.address)
#      58             self.mbSession.write_termination = self.termination
#      59             if not self.tempSess:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    1748
#    1749         if resource_pyclass is None:
# -> 1750             info = self.resource_info(resource_name, extended=True)
#    1751
#    1752             try:
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\highlevel.py in resource_info(self, resource_name, extended)
#    1702
#    1703         if extended:
# -> 1704             ret, err = self.visalib.parse_resource_extended(self.session, resource_name)
#    1705         else:
#    1706             ret, err = self.visalib.parse_resource(self.session, resource_name)
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\functions.py in parse_resource_extended(library, session, resource_name)
#    1378     # [ViSession, ViRsrc, ViPUInt16, ViPUInt16, ViAChar, ViAChar, ViAChar]
#    1379     # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1380     ret = library.viParseRsrcEx(session, resource_name, byref(interface_type),
#    1381                                 byref(interface_board_number), resource_class,
#    1382                                 unaliased_expanded_resource_name,
#
# c:\users\mrnez\appdata\local\programs\python\python38-32\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     191
#     192         if ret_value < 0:
# --> 193             raise errors.VisaIOError(ret_value)
#     194
#     195         if ret_value in self.issue_warning_on:
#
# VisaIOError: VI_ERROR_LIBRARY_NFOUND (-1073807202): A code library required by VISA could not be located or loaded.
